# %% [markdown]
# # Project HR
#
# Predict attrition of your valuable employees
#
# [IBM HR Analytics Employee Attrition & Performance](https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("data\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.pop('EmployeeNumber')
df.pop('Over18')
df.pop('StandardHours')
df.pop('EmployeeCount')
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: EmployeeCount, Length: 1470, dtype: int64

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
df_attrition=df['Attrition'].value_counts()
plot1=sns.countplot(data=df, x='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("Attrition")
# Out:
# Text(0.5, 1.0, 'Attrition')

# %%
plot1=sns.histplot(data=df, x='DailyRate')
plot1.set_title("DailyRate")
# Out:
# Text(0.5, 1.0, 'DailyRate')

# %%
plot1=sns.countplot(data=df, x='Department', hue='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("Department")
# Out:
# Text(0.5, 1.0, 'Department')

# %%
plot1=sns.countplot(data=df, x='DistanceFromHome', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("DistanceFromHome")
# Out:
# Text(0.5, 1.0, 'DistanceFromHome')

# %%
plot1=sns.countplot(data=df, x='Education',hue='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("Education")
# Out:
# Text(0.5, 1.0, 'Education')

# %%
plot1=sns.countplot(data=df, x='EnvironmentSatisfaction', hue='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("EnvironmentSatisfaction")
# Out:
# Text(0.5, 1.0, 'EnvironmentSatisfaction')

# %%
plot1=sns.countplot(data=df, x='Gender', palette = 'hls',  linewidth=2.5, edgecolor=".4")
plot1.set_title("Gender")
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
plot1=sns.countplot(data=df, x='Gender', hue='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("Gender")
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
plot1=sns.histplot(data=df, x='TotalWorkingYears', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("TotalWorkingYears")
# Out:
# Text(0.5, 1.0, 'TotalWorkingYears')

# %%
plot1=sns.countplot(data=df, x='RelationshipSatisfaction',hue='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("RelationshipSatisfaction")
# Out:
# Text(0.5, 1.0, 'RelationshipSatisfaction')

# %%
plot1=sns.countplot(data=df, x='TotalWorkingYears', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("TotalWorkingYears")
# Out:
# Text(0.5, 1.0, 'TotalWorkingYears')

# %%
plot1=sns.histplot(data=df, x='MonthlyIncome',hue='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("MonthlyIncome")
# Out:
# Text(0.5, 1.0, 'MonthlyIncome')

# %%
plot1=sns.histplot(data=df, x='Age',hue='Attrition', palette = 'hls', linewidth=2.5, edgecolor=".4")
plot1.set_title("Age")
# Out:
# Text(0.5, 1.0, 'Age')

# %%
plt.figure(figsize = (9,8))

plt.subplot(2,2,1)
sns.histplot(df, x="Age", hue="Attrition", element="poly", palette = 'hls')

plt.subplot(2,2,2)
sns.histplot(data=df, x="Age", kde=True, hue='Attrition', palette = 'hls')

plt.subplot(2,2,3)
sns.histplot(df, x="MonthlyIncome", hue="Attrition", element="poly", palette = 'hls')

plt.subplot(2,2,4)
sns.histplot(data=df, x="MonthlyIncome", hue='Attrition',  kde=True, palette = 'hls')

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import statsmodels.regression.linear_model as lm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier

# %%
x=df.iloc[:, [5,6,8,24, 27]]
y=df.iloc[:,1:2]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
classifier=LogisticRegression(fit_intercept=True)
classifier.fit(x_train, y_train)
y_pred=classifier.predict(x_test)
cm= confusion_matrix(y_test, y_pred)
cm
# Out:
# c:\Users\Personal\Desktop\test\env\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[257,   0],
#        [ 37,   0]], dtype=int64)

# %%
classifier=DecisionTreeClassifier(criterion='gini')
classifier.fit(x_train, y_train)
y_pred=classifier.predict(x_test)
cm1= confusion_matrix(y_test, y_pred)
cm1
# Out:
# array([[210,  47],
#        [ 26,  11]], dtype=int64)
